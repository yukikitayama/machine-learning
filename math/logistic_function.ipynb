# %% [markdown]
# # Logistic Function
#
# ## Dependency

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')

# %% [markdown]
# ## Sigmoid function
#
# $$
# f(x) = \frac{1}{1 + e^{-\beta x}}
# $$
#
# **Sigmoid function** looks like this

# %%
def sigmoid(x, beta):
    return np.divide(1, 1 + np.exp(-beta * x))


beta = 1
xs = np.linspace(-6, 6, 100)
ys = sigmoid(xs, beta)

plt.plot(xs, ys)
plt.title('Sigmoid')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %% [markdown]
# By multiplying sigmoid function, we can scale it beyond 1.

# %%
beta = 1
xs = np.linspace(-6, 6, 100)
ys = sigmoid(xs, beta) * 4

plt.plot(xs, ys)
plt.title('Sigmoid')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %% [markdown]
# By subtracting from sigmoid function, we can shift it.

# %%
beta = 1
xs = np.linspace(-6, 6, 100)
ys = sigmoid(xs, beta) * 2 - 1

plt.plot(xs, ys)
plt.title('Sigmoid')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %% [markdown]
# $\beta$ parameter in sigmoid function is a key parameter. Sometimes it's referred as **heat** or **temperature** parameter. It defines the steepness of sigmoid function.
#
# - Small heat, flatten sigmoid
# - Large heat, steep sigmoid, like step function

# %%
beta = 1
xs = np.linspace(-6, 6, 100)
ys = sigmoid(xs, beta) * 2 - 1
plt.plot(xs, ys, label=f'Beta: {beta}')

beta = 5
xs = np.linspace(-6, 6, 100)
ys = sigmoid(xs, beta) * 2 - 1
plt.plot(xs, ys, label=f'Beta: {beta}')

beta = 0.5
xs = np.linspace(-6, 6, 100)
ys = sigmoid(xs, beta) * 2 - 1
plt.plot(xs, ys, label=f'Beta: {beta}')


plt.title('Testing different hear parameter of sigmoid')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Logistic function
#
# **Logistic function** is a natural log of odds. $p$ is probability, $0 \le p \le 1$.
#
# $$
# \text{ln} \frac{p}{1 - p} = \beta
# $$
#
# We have the exponent and log cancel each other out.
#
# $$
# e^{\log(x)} = x
# $$
#
# By taking exponent of the both sides of logistic function,
#
# $$
# e^{\text{ln} \frac{p}{1 - p}} = e^{\beta}
# $$
# $$
# \frac{p}{1 - p} = e^{\beta}
# $$
#
# We solve for $p$.
#
# $$
# p = e^{\beta} (1 - p)
# $$
# $$
# p = e^{\beta} - e^{\beta} p
# $$
# $$
# e^{\beta} = p + e^{\beta} p
# $$
# $$
# e^{\beta} = (1 + e^{\beta}) p
# $$
# $$
# p = \frac{e^{\beta}}{1 + e^{\beta}}
# $$
#
# By multiplying both numerator and denominator by $e^{-\beta}$ on the right side,
#
# $$
# p = \frac{e^{\beta}}{1 + e^{\beta}} \frac{e^{-\beta}}{e^{-\beta}}
# $$
# $$
# = \frac{e^0}{e^{-\beta} + e^0}
# $$
# $$
# = \frac{1}{1 + e^{-\beta}}
# $$
#
# So taking exponent of logistic function returns sigmoid function.
